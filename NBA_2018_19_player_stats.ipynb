# %%
import pandas as pd

# %%
#read_csv with encoding ="ISO-8859-1" command

# %%
player_stats = pd.read_csv("C:/Users/panderson/OneDrive - Gannett Company, Incorporated/Desktop/NBA_player_stats_2018_19.csv", encoding ="ISO-8859-1")

# %%
player_stats.head()
# Out:
#    Rk                   Player Pos  Age   Tm   G  GS   MP?   FG   FGA  ...  \
# 0   1    Bradley Beal\bealbr01  SG   25  WAS  82  82  3028  764  1609  ...
# 1   2   James Harden\hardeja01  PG   29  HOU  78  78  2867  843  1909  ...
# 2   3   Kemba Walker\walkeke02  PG   28  CHO  82  82  2863  731  1684  ...
# 3   4  Tobias Harris\harrito02  PF   26  TOT  82  82  2847  611  1254  ...
# 4   5    Paul George\georgpa01  SF   28  OKC  77  77  2841  707  1614  ...
#
#      FT%  ORB  DRB  TRB  AST  STL  BLK  TOV   PF   PTS
# 0  0.808   89  322  411  448  121   58  224  226  2099
# 1  0.879   66  452  518  586  158   58  387  244  2818
# 2  0.844   52  309  361  484  102   34  211  131  2102
# 3  0.866   69  576  645  229   51   37  151  184  1644
# 4  0.839  105  523  628  318  170   34  205  214  2159
#
# [5 rows x 30 columns]

# %%
age_23 = player_stats[player_stats.Age == 23]

# %%
age_23.head()
# Out:
#     Rk                        Player Pos  Age   Tm   G  GS   MP?   FG   FGA  \
# 14  15        Aaron Gordon\gordoaa01  PF   23  ORL  78  78  2633  470  1046
# 28  29  Karl-Anthony Towns\townska01   C   23  MIN  77  77  2545  681  1314
# 29  30      Andrew Wiggins\wiggian01  SF   23  MIN  73  73  2543  498  1209
# 33  34        Nikola Jokic\jokicni01   C   23  DEN  80  80  2504  616  1206
# 39  40          Cedi Osman\osmande01  SF   23  CLE  76  75  2444  360   844
#
#     ...    FT%  ORB  DRB  TRB  AST  STL  BLK  TOV   PF   PTS
# 14  ...  0.731  129  445  574  289   57   56  162  172  1246
# 28  ...  0.836  263  691  954  259   67  125  240  292  1880
# 29  ...  0.699   83  269  352  184   70   48  138  153  1321
# 33  ...  0.821  228  637  865  580  108   55  248  228  1604
# 39  ...  0.779   45  312  357  195   60   11  114  195   991
#
# [5 rows x 30 columns]

# %%
age_23.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 59 entries, 14 to 529
# Data columns (total 30 columns):
# Rk        59 non-null int64
# Player    59 non-null object
# Pos       59 non-null object
# Age       59 non-null int64
# Tm        59 non-null object
# G         59 non-null int64
# GS        59 non-null int64
# MP?       59 non-null int64
# FG        59 non-null int64
# FGA       59 non-null int64
# FG%       58 non-null float64
# 3P        59 non-null int64
# 3PA       59 non-null int64
# 3P%       54 non-null float64
# 2P        59 non-null int64
# 2PA       59 non-null int64
# 2P%       57 non-null float64
# eFG%      58 non-null float64
# FT        59 non-null int64
# FTA       59 non-null int64
# FT%       51 non-null float64
# ORB       59 non-null int64
# DRB       59 non-null int64
# TRB       59 non-null int64
# AST       59 non-null int64
# STL       59 non-null int64
# BLK       59 non-null int64
# TOV       59 non-null int64
# PF        59 non-null int64
# ...

# %%
age_23.sort_values("PTS", ascending = False)
# Out:
#       Rk                             Player Pos  Age   Tm   G  GS   MP?   FG  \
# 28    29       Karl-Anthony Towns\townska01   C   23  MIN  77  77  2545  681
# 33    34             Nikola Jokic\jokicni01   C   23  DEN  80  80  2504  616
# 74    75              Zach LaVine\lavinza01  SG   23  CHI  63  62  2171  530
# 29    30           Andrew Wiggins\wiggian01  SF   23  MIN  73  73  2543  498
# 53    54               Kyle Kuzma\kuzmaky01  PF   23  LAL  70  68  2314  496
# 14    15             Aaron Gordon\gordoaa01  PF   23  ORL  78  78  2633  470
# 114  115              Kelly Oubre\oubreke01  SF   23  TOT  69  19  1935  375
# 39    40               Cedi Osman\osmande01  SF   23  CLE  76  75  2444  360
# 149  150            Jabari Parker\parkeja01  PF   23  TOT  64  17  1724  369
# 109  110             Monte Morris\morrimo01  PG   23  DEN  82   6  1970  346
# 218  219             Bobby Portis\portibo01  PF   23  TOT  50  28  1299  279
# ...

# %%
age_points = player_stats.groupby(["Age"]).PTS.sum().reset_index().sort_values("PTS", ascending = False)

# %%
age_counts = player_stats.groupby(["Age"]).Age.value_counts().reset_index()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-78-522e4343a09e> in <module>
# ----> 1 age_counts = player_stats.groupby(["Age"]).Age.value_counts().reset_index()
#
# c:\cygwin64\home\panderson\first-python-notebook\lib\site-packages\pandas\core\series.py in reset_index(self, level, drop, name, inplace)
#    1580         else:
#    1581             df = self.to_frame(name)
# -> 1582             return df.reset_index(level=level, drop=drop)
#    1583
#    1584     # ----------------------------------------------------------------------
#
# c:\cygwin64\home\panderson\first-python-notebook\lib\site-packages\pandas\core\frame.py in reset_index(self, level, drop, inplace, col_level, col_fill)
#    4687                 # to ndarray and maybe infer different dtype
#    4688                 level_values = _maybe_casted_values(lev, lab)
# ...

# %%
age_counts
# Out:
# Age  Age
# 19   19     11
# 20   20     25
# 21   21     42
# 22   22     44
# 23   23     59
# 24   24     47
# 25   25     49
# 26   26     44
# 27   27     33
# 28   28     39
# 29   29     28
# 30   30     31
# 31   31     18
# 32   32     19
# 33   33     17
# 34   34     10
# 35   35      3
# 36   36      3
# 37   37      3
# 38   38      3
# 40   40      1
# 42   42      1
# Name: Age, dtype: int64

# %%
#trying to figure out how to configure age_counts and then merge tables

# %%
pd.merge(age_points, age_counts, on = "Age")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-77-5a9a67b4e3f2> in <module>
# ----> 1 pd.merge(age_points, age_counts, on = "Age")
#
# c:\cygwin64\home\panderson\first-python-notebook\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      80         copy=copy,
#      81         indicator=indicator,
# ---> 82         validate=validate,
#      83     )
#      84     return op.get_result()
#
# c:\cygwin64\home\panderson\first-python-notebook\lib\site-packages\pandas\core\reshape\merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     625             self.right_join_keys,
#     626             self.join_names,
# --> 627         ) = self._get_merge_keys()
# ...
