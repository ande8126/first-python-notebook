# %%
import pandas as pd

# %%
permits_2019 = pd.read_csv(r"C:\Users\panderson\OneDrive - Gannett Company, Incorporated\Documents\notes_01132020buildingpermitsfor2019.csv")

# %%
permits_2019.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17638 entries, 0 to 17637
# Data columns (total 8 columns):
# Date            17638 non-null object
# PermitNumber    17638 non-null object
# HouseNumber     17638 non-null object
# Street          17638 non-null object
# Type            17638 non-null object
# Description     17528 non-null object
# Contractor      17623 non-null object
# Value           17638 non-null float64
# dtypes: float64(1), object(7)
# memory usage: 620.1+ KB

# %%
permits_2019.sort_values("Value", ascending = False)
# Out:
#                    Date           PermitNumber HouseNumber           Street  \
# 3836     10/1/2019 0:00  Permit-CB-135745-2019        1600      N MARION RD
# 6188     8/22/2019 0:00  Permit-CB-139745-2019        6700        E 41ST ST
# 6299     8/21/2019 0:00  Permit-CB-133579-2019        1900    N BAHNSON AVE
# 3535     10/7/2019 0:00  Permit-CB-130504-2019         500  S MINNESOTA AVE
# 13707    4/22/2019 0:00  Permit-CB-130734-2019        4700        W 69TH ST
# ...                 ...                    ...         ...              ...
# 10597     6/7/2019 0:00         LW-140530-2019        5901    W WHISTLER CT
# 4078     9/26/2019 8:00        FEN-152048-2019        3704    E BREWSTER ST
# 10599     6/7/2019 0:00        FEN-140661-2019        5608        W TEEM ST
# 10600     6/7/2019 0:00        FEN-140708-2019         700  S WHITEWOOD AVE
# 0      12/31/2019 14:38  Permit-RB-160637-2019        1200   S SYCAMORE AVE
#
#                        Type  \
# ...

# %%
permits2019 = permits_2019.dropna()

# %%
permits2019.Contractor.value_counts().reset_index().head()
# Out:
#                                     index  Contractor
# 0                          PRIDE NEON INC         349
# 1        FRISBEES MECHANICAL INC, MCL# 34         320
# 2          FRISBEES PLUMBING INC, PLU# 34         295
# 3  AMERICAN FENCE COMPANY OF SOUTH DAKOTA         256
# 4               SORLIEN ELECTRIC, ELC# 70         238

# %%
journeypermits = permits2019[permits2019.Contractor.str.contains('journey', case=False)]

# %%
journeypermits.sort_values("Value", ascending = False)
# Out:
#                    Date           PermitNumber HouseNumber          Street  \
# 16015    2/28/2019 0:00  Permit-CB-116972-2018        1325     S CLIFF AVE
# 10344    6/11/2019 0:00  Permit-CB-139013-2019        1600     N MARION RD
# 15433    3/20/2019 0:00  Permit-CB-121784-2018        6800    S LOUISE AVE
# 2582    10/23/2019 0:00  Permit-CB-155325-2019        4400       W 69TH ST
# 5429      9/6/2019 0:00  Permit-CB-144226-2019        1702       S 7TH AVE
# 17125    1/18/2019 0:00  Permit-CB-129013-2019        6800    S LOUISE AVE
# 453     12/12/2019 0:00  Permit-CB-150548-2019         600  N EBENEZER AVE
# 1172    11/21/2019 0:00  Permit-CB-154455-2019         316  S PHILLIPS AVE
# 1295    11/19/2019 0:00  Permit-CB-157581-2019        3900      W AVERA DR
# 15674    3/13/2019 0:00  Permit-CB-127551-2018        1325     S CLIFF AVE
# 3189    10/15/2019 0:00  Permit-CB-150781-2019         316  S PHILLIPS AVE
# ...

# %%
journeypermits.Value.sum()
# Out:
# 67654050.0

# %%
permits2019.groupby("Contractor").Value.sum().reset_index().sort_values("Value", ascending=False)
# Out:
#                                     Contractor       Value
# 1751                   JOURNEY GROUP COMPANIES  67528050.0
# 1634                             JOE NIEWOHNER  59023819.0
# 2039                LLOYD CONSTRUCTION COMPANY  44707694.0
# 1137                       FIEGEN CONSTRUCTION  34350700.0
# 1336            HENRY CARLSON CONSTRUCTION LLC  29302868.0
# ...                                        ...         ...
# 689   COUNTY LINE BUILDERS LLC - ANTHONY BOYER         0.0
# 687              COUNTRY VIEW MOBILE HOME PARK         0.0
# 684                               CORY SAMPSON         0.0
# 2428                               OLIN ODLAND         0.0
# 3429                     ZOOM FIX LLP, FPC# 11         0.0
#
# [3430 rows x 2 columns]
